# %% [markdown]
# <a href="https://colab.research.google.com/github/jarhead234/Akbank-Deep-Learning-Bootcamp-REPO/blob/main/Colab'e_ho%C5%9F_geldiniz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
